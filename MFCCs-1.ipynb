# %%
# MFCCs1
#
# created by ravissement on 2021-11.25

import matplotlib.pyplot as plt
import librosa.display
import librosa
import numpy as np


path = 'D:/ravissement/labelig/train/0001.wav'
sample_rate=8000

x = librosa.load(path,sample_rate)[0]
S = librosa.feature.melspectrogram(x, sr=sample_rate, n_mels=128)


min_level_db= -100
def normalize_mel(S):
    return np.clip((S-min_level_db)/-min_level_db,0,1)


def feature_extraction(path):
    y = librosa.load(path,16000)[0]
    S =  librosa.feature.melspectrogram(y=y, n_mels=80, n_fft=512, win_length=400, hop_length=160)
    norm_log_S = normalize_mel(librosa.power_to_db(S, ref=np.max))
    return norm_log_S

a = feature_extraction(path)
librosa.display.specshow(a, y_axis='mel', x_axis='time')

#plt.colorbar(format='%+2.0f dB')
plt.title('Mel-Spectrogram')
plt.tight_layout()
#plt.savefig('Mel-Spectrogram example.png')
plt.show()

# %%
#log_S = librosa.power_to_db(S, ref=np.max)
mfcc = librosa.feature.mfcc(S=log_S, n_mfcc=20)

plt.figure(figsize=(12, 4))
librosa.display.specshow(mfcc)
plt.ylabel('MFCC coeffs')
plt.xlabel('Time')
plt.title('MFCC')
#plt.colorbar()
plt.tight_layout()

# %%
delta2_mfcc = librosa.feature.delta(mfcc, order=2)

plt.figure(figsize=(12, 4))
librosa.display.specshow(delta2_mfcc)
plt.ylabel('MFCC coeffs')
plt.xlabel('Time')
plt.title('MFCC')
#plt.colorbar()
plt.tight_layout()

# %%
import os
import numpy as np
import librosa
import librosa.display
import matplotlib.pyplot as plt 


min_level_db= -100
def normalize_mel(S):
    return np.clip((S-min_level_db)/-min_level_db,0,1)


def feature_extraction(path):
    y = librosa.load(path,16000)[0]
    S =  librosa.feature.melspectrogram(y=y, n_mels=80, n_fft=512, win_length=400, hop_length=160)
    norm_log_S = normalize_mel(librosa.power_to_db(S, ref=np.max))
    return norm_log_S
                        
# recorded my voice..(by guitar)
# tamia - officially missing you 
a = feature_extraction('d:/ravissement/pythonData/train16K/omy_16k.wav')  
librosa.display.specshow(a, y_axis='mel', x_axis='time')

plt.colorbar(format='%+2.0f dB')
plt.title('Mel-Spectrogram')
plt.tight_layout()
#plt.savefig('Mel-Spectrogram example.png')
plt.show()
